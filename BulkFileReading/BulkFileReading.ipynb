# %%
import os

# %%
files = os.listdir('Files')

# %%
files
# Out:
# ['.ipynb_checkpoints',
#  'file - Copy (10) - Copy - Copy.txt',
#  'file - Copy (10) - Copy.txt',
#  'file - Copy (10).txt',
#  'file - Copy (11) - Copy - Copy.txt',
#  'file - Copy (11) - Copy.txt',
#  'file - Copy (11).txt',
#  'file - Copy (12) - Copy - Copy.txt',
#  'file - Copy (12) - Copy.txt',
#  'file - Copy (12).txt',
#  'file - Copy (13) - Copy - Copy.txt',
#  'file - Copy (13) - Copy.txt',
#  'file - Copy (13).txt',
#  'file - Copy (14) - Copy - Copy.txt',
#  'file - Copy (14) - Copy.txt',
#  'file - Copy (14).txt',
#  'file - Copy (15) - Copy - Copy.txt',
#  'file - Copy (15) - Copy.txt',
#  'file - Copy (15).txt',
#  'file - Copy (16) - Copy - Copy.txt',
#  'file - Copy (16) - Copy.txt',
#  'file - Copy (16).txt',
#  'file - Copy (17) - Copy - Copy.txt',
#  'file - Copy (17) - Copy.txt',
#  'file - Copy (17).txt',
#  'file - Copy (18) - Copy - Copy.txt',
#  'file - Copy (18) - Copy.txt',
#  'file - Copy (18).txt',
#  'file - Copy (19) - Copy - Copy.txt',
# ...

# %%
len(files)
# Out:
# 163

# %%
fd2 = open("CombinedData.txt",'a')
for i in files:
    if i != '.ipynb_checkpoints':
        fd = open('Files/'+i,'r')
        fd2.write(fd.read()+'\n')
        fd.close()
fd2.close()
